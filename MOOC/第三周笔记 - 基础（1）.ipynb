# %%
#本地文件打开
file_obj = open(filename, mode, buffering)
mode: r-read; a-append; w-write； a+; w+; r+; 二进制模式rb,ab,wb
buffering:默认-1，0代表不缓冲，1或大于1的值表示缓冲一行或指定缓冲区大小

# %%
关闭和读写文件相关的方法/函数
f.read(), f.write(), f.readline(), f.readlines(), f.writelines()
f.close()
f.seek()

# %%
file_obj.seek(offset, whence=0)
文件中移动文件指针，从whence（0表示文件头部，1表示当前位置，2表示文件尾部）偏移offset个字节
whence参数可选，默认值为0

# %%
标准文件.ipynb（？）*
= sys & stdin, stdout, stderr

# %%
#网络数据获取
HOW? 抓取网页，解析网页内容
- 抓取
    - urlib内建模块
        - urlib.request
    - requests 第三方库
    - scrapy 框架
- 解析
    - BeautifulSoup库
    - re模块

# %%
#request库
import requests
r= requests.get('https://book.douban.com/subject/1084336/comments/')
r.status_code
print(r.text)
#抓取到了《小王子》的短评
# Out:
# <!DOCTYPE html>
# <html lang="zh-cmn-Hans" class=" book-new-nav">
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#   <title>
#     小王子 短评
# </title>
#
# ...

# %%
#利用requests库获取道指成分股数据

# %%
网页数据解析
- BeautifulSoup可以从HTML或XML文件中提取数据的Python库。
- 正则进行各类正则表达式处理
